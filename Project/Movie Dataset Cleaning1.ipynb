# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("25k IMDb movie Dataset.csv")

# %%
data.head()
# Out:
#                movie title                  Run Time Rating User Rating  \
# 0        Top Gun: Maverick  $170,000,000 (estimated)    8.6        187K
# 1  Jurassic World Dominion        2 hours 27 minutes      6         56K
# 2                  Top Gun   $15,000,000 (estimated)    6.9        380K
# 3                Lightyear               $71,101,257    5.2         32K
# 4               Spiderhead              not-released    5.4         23K
#
#                                 Generes  \
# 0                   ['Action', 'Drama']
# 1     ['Action', 'Adventure', 'Sci-Fi']
# 2                   ['Action', 'Drama']
# 3  ['Animation', 'Action', 'Adventure']
# 4          ['Action', 'Crime', 'Drama']
#
#                                             Overview  \
# 0  After more than thirty years of service as one...
# 1  Four years after the destruction of Isla Nubla...
# 2  As students at the United States Navy's elite ...
# 3  While spending years attempting to return home...
# ...

# %%
data.tail()
# Out:
#           movie title                    Run Time Rating User Rating  \
# 24397    Delicatessen  FRF 24,000,000 (estimated)    7.6         85K
# 24398       Bitch Ass                not-released    5.5          52
# 24399        Bullwhip                not-released    5.1         398
# 24400    The Freshman           1 hour 42 minutes    6.4         20K
# 24401  Guys and Dolls      $5,500,000 (estimated)    7.1         18K
#
#                                Generes  \
# 24397              ['Comedy', 'Crime']
# 24398              ['Crime', 'Horror']
# 24399  ['Crime', 'Romance', 'Western']
# 24400              ['Comedy', 'Crime']
# 24401   ['Comedy', 'Crime', 'Musical']
#
#                                                 Overview  \
# 24397  Post-apocalyptic surrealist black comedy about...
# 24398  A gang initiation goes wrong when a group of f...
# 24399  In order to avoid the hangman's noose, a cowbo...
# 24400  An N.Y.C. film school student accepts a job wi...
# ...

# %%
data.columns
# Out:
# Index(['movie title', 'Run Time', 'Rating', 'User Rating', 'Generes',
#        'Overview', 'Plot Kyeword', 'Director', 'Top 5 Casts', 'Writer', 'year',
#        'path'],
#       dtype='object')

# %%
data.count()
# Out:
# movie title     24402
# Run Time        24402
# Rating          24402
# User Rating     24402
# Generes         24402
# Overview        24158
# Plot Kyeword    24402
# Director        24402
# Top 5 Casts     24402
# Writer          24402
# year            23624
# path            24402
# dtype: int64

# %%
data.nunique()
# Out:
# movie title     23922
# Run Time         1556
# Rating             91
# User Rating      1684
# Generes           746
# Overview        23957
# Plot Kyeword    21546
# Director        11604
# Top 5 Casts     24211
# Writer          15562
# year              250
# path            23922
# dtype: int64

# %%
del(data['path'])

# %%
del(data['Overview'])

# %%
del(data['Plot Kyeword'])

# %%
data
# Out:
#                    movie title                    Run Time Rating User Rating  \
# 0            Top Gun: Maverick    $170,000,000 (estimated)    8.6        187K
# 1      Jurassic World Dominion          2 hours 27 minutes      6         56K
# 2                      Top Gun     $15,000,000 (estimated)    6.9        380K
# 3                    Lightyear                 $71,101,257    5.2         32K
# 4                   Spiderhead                not-released    5.4         23K
# ...                        ...                         ...    ...         ...
# 24397             Delicatessen  FRF 24,000,000 (estimated)    7.6         85K
# 24398                Bitch Ass                not-released    5.5          52
# 24399                 Bullwhip                not-released    5.1         398
# 24400             The Freshman           1 hour 42 minutes    6.4         20K
# 24401           Guys and Dolls      $5,500,000 (estimated)    7.1         18K
#
# ...

# %%
data.dtypes
# Out:
# movie title    object
# Run Time       object
# Rating         object
# User Rating    object
# Generes        object
# Director       object
# Top 5 Casts    object
# Writer         object
# year           object
# dtype: object

# %%
data[data['year'].isnull()]
# Out:
#              movie title            Run Time     Rating User Rating  \
# 495             Napoleon        not-released  no-rating           0
# 496             Napoleon  5 hours 30 minutes        8.2        7.8K
# 562      I Saw the Devil  2 hours 24 minutes        7.8        127K
# 563      I Saw the Devil        not-released  no-rating           0
# 717    Sherlock Holmes 3        not-released  no-rating           0
# ...                  ...                 ...        ...         ...
# 24253          L.A. Rush        not-released  no-rating           0
# 24270         Crimelands        not-released  no-rating           0
# 24303     Catch and Kill        not-released  no-rating           0
# 24304         Rent-a-Man        not-released  no-rating           0
# 24321              8 1/2        not-released  no-rating           0
#
#                                   Generes         Director  \
# 495      ['Action', 'Biography', 'Drama']     Ridley Scott
# ...

# %%
data.dropna(subset= ['year'], inplace= True)

# %%
data
# Out:
#                    movie title                    Run Time Rating User Rating  \
# 0            Top Gun: Maverick    $170,000,000 (estimated)    8.6        187K
# 1      Jurassic World Dominion          2 hours 27 minutes      6         56K
# 2                      Top Gun     $15,000,000 (estimated)    6.9        380K
# 3                    Lightyear                 $71,101,257    5.2         32K
# 4                   Spiderhead                not-released    5.4         23K
# ...                        ...                         ...    ...         ...
# 24397             Delicatessen  FRF 24,000,000 (estimated)    7.6         85K
# 24398                Bitch Ass                not-released    5.5          52
# 24399                 Bullwhip                not-released    5.1         398
# 24400             The Freshman           1 hour 42 minutes    6.4         20K
# 24401           Guys and Dolls      $5,500,000 (estimated)    7.1         18K
#
# ...

# %%
data.nunique()
# Out:
# movie title    23153
# Run Time        1553
# Rating            91
# User Rating     1684
# Generes          737
# Director       11294
# Top 5 Casts    23545
# Writer         15181
# year             250
# dtype: int64

# %%
data[data['movie title'].duplicated()]
# Out:
#                movie title           Run Time Rating User Rating  \
# 7              Interceptor  1 hour 30 minutes    3.6         819
# 18            Bullet Train       not-released    6.8        1.3K
# 29                    Prey       not-released    5.2         961
# 30                    Prey  1 hour 48 minutes    5.3        2.5K
# 32               Ambulance  1 hour 20 minutes    5.3        1.4K
# ...                    ...                ...    ...         ...
# 22309             The Isle  1 hour 36 minutes    5.3         13K
# 22482  The Concrete Jungle  1 hour 26 minutes    6.8        1.6K
# 22635           The Bunker       not-released    5.4          6K
# 22720         Almost Human       not-released    7.2        2.5K
# 22740               Escape       not-released    3.5          50
#
#                                   Generes                Director  \
# 7        ['Action', 'Sci-Fi', 'Thriller']     Konstantin Maksimov
# ...

# %%
data.drop_duplicates(subset=['movie title'], inplace= True)

# %%
data
# Out:
#                    movie title                    Run Time Rating User Rating  \
# 0            Top Gun: Maverick    $170,000,000 (estimated)    8.6        187K
# 1      Jurassic World Dominion          2 hours 27 minutes      6         56K
# 2                      Top Gun     $15,000,000 (estimated)    6.9        380K
# 3                    Lightyear                 $71,101,257    5.2         32K
# 4                   Spiderhead                not-released    5.4         23K
# ...                        ...                         ...    ...         ...
# 24397             Delicatessen  FRF 24,000,000 (estimated)    7.6         85K
# 24398                Bitch Ass                not-released    5.5          52
# 24399                 Bullwhip                not-released    5.1         398
# 24400             The Freshman           1 hour 42 minutes    6.4         20K
# 24401           Guys and Dolls      $5,500,000 (estimated)    7.1         18K
#
# ...

# %%
data['Run Time'].value_counts()
# Out:
# not-released                  7558
# 1 hour 30 minutes              491
# 1 hour 35 minutes              367
# 1 hour 38 minutes              345
# 1 hour 31 minutes              334
#                               ...
# $795,000 (estimated)             1
# $6,900,000 (estimated)           1
# $28,596,818                      1
# $22,873,653                      1
# FRF 24,000,000 (estimated)       1
# Name: Run Time, Length: 1524, dtype: int64

# %%
del(data['Run Time'])

# %%
data
# Out:
#                    movie title Rating User Rating  \
# 0            Top Gun: Maverick    8.6        187K
# 1      Jurassic World Dominion      6         56K
# 2                      Top Gun    6.9        380K
# 3                    Lightyear    5.2         32K
# 4                   Spiderhead    5.4         23K
# ...                        ...    ...         ...
# 24397             Delicatessen    7.6         85K
# 24398                Bitch Ass    5.5          52
# 24399                 Bullwhip    5.1         398
# 24400             The Freshman    6.4         20K
# 24401           Guys and Dolls    7.1         18K
#
#                                     Generes              Director  \
# 0                       ['Action', 'Drama']       Joseph Kosinski
# 1         ['Action', 'Adventure', 'Sci-Fi']       Colin Trevorrow
# 2                       ['Action', 'Drama']            Tony Scott
# 3      ['Animation', 'Action', 'Adventure']         Angus MacLane
# ...

# %%
data['Rating'].value_counts()
# Out:
# no-rating    948
# 6.4          833
# 6.2          832
# 6.3          798
# 6.1          796
#             ...
# 9.9            2
# 9.8            2
# 9.4            2
# 1              2
# 9.5            2
# Name: Rating, Length: 91, dtype: int64

# %%
data['User Rating'].value_counts()
# Out:
# 0       948
# 11K     320
# 1.2K    316
# 1.1K    312
# 1.3K    286
#        ...
# 674K      1
# 614K      1
# 452K      1
# 530K      1
# 347K      1
# Name: User Rating, Length: 1681, dtype: int64

# %%
data[data['User Rating'] == '0']
# Out:
#                     movie title     Rating User Rating  \
# 8                    Black Adam  no-rating           0
# 17                 Bullet Train  no-rating           0
# 28                         Prey  no-rating           0
# 38                 The Gray Man  no-rating           0
# 59     Avatar: The Way of Water  no-rating           0
# ...                         ...        ...         ...
# 24242             Scheme Queens  no-rating           0
# 24311                 Penthouse  no-rating           0
# 24355                 Now I See  no-rating           0
# 24377                Flycatcher  no-rating           0
# 24379                Breakwater  no-rating           0
#
#                                  Generes                  Director  \
# 8        ['Action', 'Fantasy', 'Sci-Fi']        Jaume Collet-Serra
# 17                ['Action', 'Thriller']              David Leitch
# 28         ['Action', 'Drama', 'Horror']          Dan Trachtenberg
# ...

# %%
data[(data['User Rating'] == '0') & (data['Rating'] =='no-rating')]
# Out:
#                     movie title     Rating User Rating  \
# 8                    Black Adam  no-rating           0
# 17                 Bullet Train  no-rating           0
# 28                         Prey  no-rating           0
# 38                 The Gray Man  no-rating           0
# 59     Avatar: The Way of Water  no-rating           0
# ...                         ...        ...         ...
# 24242             Scheme Queens  no-rating           0
# 24311                 Penthouse  no-rating           0
# 24355                 Now I See  no-rating           0
# 24377                Flycatcher  no-rating           0
# 24379                Breakwater  no-rating           0
#
#                                  Generes                  Director  \
# 8        ['Action', 'Fantasy', 'Sci-Fi']        Jaume Collet-Serra
# 17                ['Action', 'Thriller']              David Leitch
# 28         ['Action', 'Drama', 'Horror']          Dan Trachtenberg
# ...

# %%
data = data[~((data['User Rating'] == '0') & (data['Rating'] == 'no-rating'))] 
# ~negates the condition to keep only the rows that don't match

# %%
data.columns= ['Movie Title', 'Rating','User Rating','Genre','Director','Top Casts','Writer','Year']

# %%
data.head()
# Out:
#                Movie Title Rating User Rating  \
# 0        Top Gun: Maverick    8.6        187K
# 1  Jurassic World Dominion      6         56K
# 2                  Top Gun    6.9        380K
# 3                Lightyear    5.2         32K
# 4               Spiderhead    5.4         23K
#
#                                   Genre         Director  \
# 0                   ['Action', 'Drama']  Joseph Kosinski
# 1     ['Action', 'Adventure', 'Sci-Fi']  Colin Trevorrow
# 2                   ['Action', 'Drama']       Tony Scott
# 3  ['Animation', 'Action', 'Adventure']    Angus MacLane
# 4          ['Action', 'Crime', 'Drama']  Joseph Kosinski
#
#                                            Top Casts            Writer   Year
# 0  ['Jack Epps Jr.', 'Peter Craig', 'Tom Cruise',...          Jim Cash  -2022
# 1  ['Colin Trevorrow', 'Derek Connolly', 'Chris P...  Emily Carmichael  -2022
# 2  ['Jack Epps Jr.', 'Ehud Yonay', 'Tom Cruise', ...          Jim Cash  -1986
# ...

# %%
data['Genre'].value_counts()
# Out:
# ['Action', 'Crime', 'Drama']         824
# ['Drama']                            822
# ['Comedy', 'Drama', 'Romance']       595
# ['Crime', 'Drama', 'Thriller']       568
# ['Crime', 'Drama']                   506
#                                     ...
# ['Adventure', 'Action', 'Drama']       1
# ['Comedy', 'Musical', 'Drama']         1
# ['Horror', 'Music', 'Sci-Fi']          1
# ['Animation', 'Fantasy', 'Music']      1
# ['Crime', 'Romance', 'Western']        1
# Name: Genre, Length: 725, dtype: int64

# %%
data['Director'].value_counts()
# Out:
# Woody Allen                    46
# Clint Eastwood                 38
# Alfred Hitchcock               36
# John Ford                      32
# Henry Hathaway                 31
#                                ..
# Antoneta Alamat Kusijanovic     1
# Machete Bang Bang               1
# Yvan Attal                      1
# Filippo Meneghetti              1
# Bill Posley                     1
# Name: Director, Length: 10638, dtype: int64

# %%
data['Top Casts'].value_counts()
# Out:
# ['J.K. Rowling', 'Daniel Radcliffe', 'Emma Watson', 'Rupert Grint', 'David Yates']                 4
# ['Lilly Wachowski', 'Lana Wachowski', 'Keanu Reeves', 'Laurence Fishburne', 'Carrie-Anne Moss']    3
# ['Sylvester Stallone', 'Talia Shire', 'Burt Young', 'Sylvester Stallone', 'Sylvester Stallone']    3
# ['Henning Bahs', 'Ove Sprogøe', 'Morten Grunwald', 'Poul Bundgaard', 'Erik Balling']               3
# ['Mammootty', 'Mukesh', 'Jagathi Sreekumar', 'K. Madhu', 'S.N. Swamy']                             3
#                                                                                                   ..
# ['Lukas Heller', 'Bette Davis', 'Joan Crawford', 'Victor Buono', 'Robert Aldrich']                 1
# ['David Lynch', 'Nicolas Cage', 'Laura Dern', 'Willem Dafoe', 'David Lynch']                       1
# ['Vanessa Kirby', 'Shia LaBeouf', 'Ellen Burstyn', 'Kornél Mundruczó', 'Kata Wéber']               1
# ...

# %%
data['Year'].value_counts()
# Out:
# -2021          1027
# -2019           897
# -2018           791
# -2017           763
# -2020           761
#                ...
# (I) (1985)        1
# (I) (1981)        1
# (II) (1996)       1
# (I) (1932)        1
# (II) (1951)       1
# Name: Year, Length: 235, dtype: int64

# %%
data['Rating'] = data['Rating'].astype(float)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_18472\2717106438.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Rating'] = data['Rating'].astype(float)

# %%
pd.options.mode.chained_assignment = None

# %%
data.dtypes
# Out:
# Movie Title     object
# Rating         float64
# User Rating     object
# Genre           object
# Director        object
# Top Casts       object
# Writer          object
# Year            object
# dtype: object

# %%
# data['Year'] = data['Year'].to_string()

# %%
#data['Year'] = data['Year'].str.replace('-', '', regex=True)

# %%
#data['Year'] = data['Year'].str.replace('(', '', regex=True)

# %%
#data['Year'] = data['Year'].str.replace(')', '', regex=True)

# %%
#data['Year'] = data['Year'].str.replace('I', '', regex=True)

# %% [markdown]
# # These modification would be done by using the Spreadsheet application i.e. MS Excel

# %% [markdown]
# # And further Data Cleaning will be done by using MS Excel only.

# %%
data.to_excel('Movie Dataset.xlsx', sheet_name='Records', index= False)
